# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import keras
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils import np_utils
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape)
# Out:
# (60000, 28, 28) (60000,)

# %%
x_train= x_train.reshape(x_train.shape[0],28,28,1)
x_test=  x_test.reshape(x_test.shape[0],28,28,1)
input_shape=(28,28,1)
y_train=keras.utils.np_utils.to_categorical(y_train)#,num_classes=)
y_test=keras.utils.np_utils.to_categorical(y_test)#, num_classes)
x_train= x_train.astype('float32')
x_test= x_test.astype('float32')
x_train /= 255
x_test /=255

# %%
batch_size=64

num_classes=10

epochs=10

def build_model(activation):
  

  model=Sequential()

  model.add(Conv2D(32,kernel_size=(3,3),activation=activation,input_shape=input_shape))

  model.add(MaxPooling2D(pool_size=(2,2)))

  model.add(Dropout(0.25))

  model.add(Flatten())

  model.add(Dense(256, activation=activation))

  model.add(Dropout(0.5))

  model.add(Dense(num_classes, activation='softmax'))

  model.compile(loss=tf.keras.losses.categorical_crossentropy, optimizer= 'adam', metrics=['accuracy'])

  return model

# %%
print(x_test.shape, y_test.shape)
# Out:
# (10000, 28, 28, 1) (10000, 10)

# %%
activation = ['LeakyReLU','ELU','PReLU','sigmoid', 'tanh', 'relu',]
n=1
for i in activation:

  model = build_model(i)

  hist=model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test,y_test))
  print("Model complete for activation "+i)
  import matplotlib.pyplot as plt
  plt.subplot(2,1,1)
  plt.plot(hist.history["accuracy"])
  plt.plot(hist.history['val_accuracy'])

  plt.title("model accuracy for activation "+ i)
  plt.ylabel("Accuracy")
  plt.xlabel("Epoch")
  plt.legend(["Accuracy","Validation Accuracy"])
  
  plt.subplot(2,1,2)
  plt.plot(hist.history['loss'])
  plt.plot(hist.history['val_loss'])
  plt.title("Model Loss for "+i)
  plt.ylabel("Loss")
  plt.xlabel("Epoch")
  plt.legend(["loss","Validation Loss"])
  plt.show()
# Out:
# Epoch 1/10
# 938/938 [==============================] - 9s 8ms/step - loss: 0.2260 - accuracy: 0.9324 - val_loss: 0.0804 - val_accuracy: 0.9754
# Epoch 2/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0958 - accuracy: 0.9711 - val_loss: 0.0605 - val_accuracy: 0.9785
# Epoch 3/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0800 - accuracy: 0.9748 - val_loss: 0.0519 - val_accuracy: 0.9829
# Epoch 4/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0703 - accuracy: 0.9782 - val_loss: 0.0468 - val_accuracy: 0.9852
# Epoch 5/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0636 - accuracy: 0.9804 - val_loss: 0.0478 - val_accuracy: 0.9842
# Epoch 6/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0578 - accuracy: 0.9812 - val_loss: 0.0468 - val_accuracy: 0.9844
# Epoch 7/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0539 - accuracy: 0.9829 - val_loss: 0.0424 - val_accuracy: 0.9854
# Epoch 8/10
# 938/938 [==============================] - 8s 8ms/step - loss: 0.0510 - accuracy: 0.9839 - val_loss: 0.0515 - val_accuracy: 0.9831
# Epoch 9/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0460 - accuracy: 0.9847 - val_loss: 0.0504 - val_accuracy: 0.9841
# Epoch 10/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0464 - accuracy: 0.9852 - val_loss: 0.0480 - val_accuracy: 0.9850
# Model complete for activation LeakyReLU
# Epoch 1/10
# 938/938 [==============================] - 8s 7ms/step - loss: 0.2464 - accuracy: 0.9244 - val_loss: 0.1043 - val_accuracy: 0.9669
# Epoch 2/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.1238 - accuracy: 0.9615 - val_loss: 0.0777 - val_accuracy: 0.9749
# Epoch 3/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0979 - accuracy: 0.9686 - val_loss: 0.0661 - val_accuracy: 0.9784
# Epoch 4/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0834 - accuracy: 0.9738 - val_loss: 0.0629 - val_accuracy: 0.9795
# Epoch 5/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0724 - accuracy: 0.9772 - val_loss: 0.0557 - val_accuracy: 0.9819
# Epoch 6/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0660 - accuracy: 0.9789 - val_loss: 0.0525 - val_accuracy: 0.9833
# Epoch 7/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0605 - accuracy: 0.9807 - val_loss: 0.0543 - val_accuracy: 0.9843
# Epoch 8/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0528 - accuracy: 0.9823 - val_loss: 0.0551 - val_accuracy: 0.9835
# Epoch 9/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0494 - accuracy: 0.9842 - val_loss: 0.0513 - val_accuracy: 0.9856
# Epoch 10/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0482 - accuracy: 0.9839 - val_loss: 0.0452 - val_accuracy: 0.9872
# Model complete for activation ELU
# Epoch 1/10
# 938/938 [==============================] - 10s 10ms/step - loss: 0.2188 - accuracy: 0.9338 - val_loss: 0.0679 - val_accuracy: 0.9785
# Epoch 2/10
# 938/938 [==============================] - 9s 9ms/step - loss: 0.0868 - accuracy: 0.9737 - val_loss: 0.0486 - val_accuracy: 0.9835
# Epoch 3/10
# 938/938 [==============================] - 8s 9ms/step - loss: 0.0657 - accuracy: 0.9803 - val_loss: 0.0468 - val_accuracy: 0.9845
# Epoch 4/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.0538 - accuracy: 0.9834 - val_loss: 0.0381 - val_accuracy: 0.9873
# Epoch 5/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.0467 - accuracy: 0.9852 - val_loss: 0.0377 - val_accuracy: 0.9869
# Epoch 6/10
# 938/938 [==============================] - 8s 9ms/step - loss: 0.0413 - accuracy: 0.9868 - val_loss: 0.0341 - val_accuracy: 0.9875
# Epoch 7/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.0362 - accuracy: 0.9883 - val_loss: 0.0362 - val_accuracy: 0.9873
# Epoch 8/10
# 938/938 [==============================] - 8s 9ms/step - loss: 0.0332 - accuracy: 0.9893 - val_loss: 0.0336 - val_accuracy: 0.9882
# Epoch 9/10
# 938/938 [==============================] - 8s 9ms/step - loss: 0.0288 - accuracy: 0.9907 - val_loss: 0.0344 - val_accuracy: 0.9888
# Epoch 10/10
# 938/938 [==============================] - 9s 10ms/step - loss: 0.0268 - accuracy: 0.9912 - val_loss: 0.0351 - val_accuracy: 0.9890
# Model complete for activation PReLU
# Epoch 1/10
# 938/938 [==============================] - 8s 7ms/step - loss: 2.3988 - accuracy: 0.1022 - val_loss: 2.3021 - val_accuracy: 0.1032
# Epoch 2/10
# 938/938 [==============================] - 7s 7ms/step - loss: 2.1651 - accuracy: 0.1854 - val_loss: 1.6803 - val_accuracy: 0.6165
# Epoch 3/10
# 938/938 [==============================] - 7s 7ms/step - loss: 1.4060 - accuracy: 0.5225 - val_loss: 0.7479 - val_accuracy: 0.8372
# Epoch 4/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.8837 - accuracy: 0.7210 - val_loss: 0.4009 - val_accuracy: 0.9011
# Epoch 5/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.6827 - accuracy: 0.7891 - val_loss: 0.3391 - val_accuracy: 0.9064
# Epoch 6/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.6017 - accuracy: 0.8136 - val_loss: 0.2927 - val_accuracy: 0.9152
# Epoch 7/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.5501 - accuracy: 0.8305 - val_loss: 0.2734 - val_accuracy: 0.9210
# Epoch 8/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.5155 - accuracy: 0.8430 - val_loss: 0.2505 - val_accuracy: 0.9287
# Epoch 9/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.4835 - accuracy: 0.8532 - val_loss: 0.2336 - val_accuracy: 0.9301
# Epoch 10/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.4583 - accuracy: 0.8594 - val_loss: 0.2115 - val_accuracy: 0.9356
# Model complete for activation sigmoid
# Epoch 1/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.2558 - accuracy: 0.9220 - val_loss: 0.1077 - val_accuracy: 0.9642
# Epoch 2/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.1284 - accuracy: 0.9610 - val_loss: 0.0857 - val_accuracy: 0.9728
# Epoch 3/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.1015 - accuracy: 0.9686 - val_loss: 0.0809 - val_accuracy: 0.9749
# Epoch 4/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0893 - accuracy: 0.9715 - val_loss: 0.0584 - val_accuracy: 0.9820
# Epoch 5/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0797 - accuracy: 0.9746 - val_loss: 0.0587 - val_accuracy: 0.9812
# Epoch 6/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0697 - accuracy: 0.9778 - val_loss: 0.0613 - val_accuracy: 0.9808
# Epoch 7/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0644 - accuracy: 0.9796 - val_loss: 0.0628 - val_accuracy: 0.9805
# Epoch 8/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0564 - accuracy: 0.9817 - val_loss: 0.0542 - val_accuracy: 0.9822
# Epoch 9/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0546 - accuracy: 0.9820 - val_loss: 0.0543 - val_accuracy: 0.9838
# Epoch 10/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0518 - accuracy: 0.9829 - val_loss: 0.0509 - val_accuracy: 0.9840
# Model complete for activation tanh
# Epoch 1/10
# 938/938 [==============================] - 8s 8ms/step - loss: 0.2403 - accuracy: 0.9268 - val_loss: 0.0762 - val_accuracy: 0.9765
# Epoch 2/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0962 - accuracy: 0.9711 - val_loss: 0.0502 - val_accuracy: 0.9836
# Epoch 3/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0698 - accuracy: 0.9785 - val_loss: 0.0448 - val_accuracy: 0.9837
# Epoch 4/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0573 - accuracy: 0.9821 - val_loss: 0.0405 - val_accuracy: 0.9861
# Epoch 5/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0485 - accuracy: 0.9847 - val_loss: 0.0367 - val_accuracy: 0.9871
# Epoch 6/10
# 938/938 [==============================] - 7s 8ms/step - loss: 0.0415 - accuracy: 0.9864 - val_loss: 0.0349 - val_accuracy: 0.9884
# Epoch 7/10
# 938/938 [==============================] - 7s 8ms/step - loss: 0.0357 - accuracy: 0.9882 - val_loss: 0.0351 - val_accuracy: 0.9885
# Epoch 8/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0328 - accuracy: 0.9887 - val_loss: 0.0346 - val_accuracy: 0.9890
# Epoch 9/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0281 - accuracy: 0.9908 - val_loss: 0.0312 - val_accuracy: 0.9902
# Epoch 10/10
# 938/938 [==============================] - 7s 8ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.0377 - val_accuracy: 0.9886
# Model complete for activation relu
